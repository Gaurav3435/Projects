# %%
import turtle

turtle.shape("turtle")
turtle.speed(10)

turtle.left(90)
turtle.forward(50)
turtle.left(90)
turtle.forward(10)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(20)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(8)
turtle.left(270)

turtle.left(180)
turtle.forward(100)
turtle.left(90)
turtle.forward(10)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(20)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(8)

turtle.left(90)
turtle.forward(50)
turtle.left(270)
turtle.forward(50)
turtle.left(90)
turtle.forward(50)

turtle.left(90)
turtle.forward(10)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(20)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(8)
turtle.left(270)


turtle.left(180)
turtle.forward(100)
turtle.left(90)
turtle.forward(10)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(20)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(8)
turtle.left(90)
turtle.forward(50)

turtle.left(270)
turtle.forward(3)

turtle.left(270)
turtle.forward(50)
turtle.left(90)
turtle.forward(25)

turtle.left(90)
turtle.forward(50)
turtle.left(90)
turtle.forward(5)
turtle.left(270)
turtle.forward(5)
turtle.left(270)
turtle.forward(10)
turtle.left(270)
turtle.forward(5)

turtle.left(270)
turtle.forward(3)

turtle.left(90)
turtle.forward(50)
turtle.left(90)

turtle.exitonclick()
